# %% [markdown]
# <a href="https://colab.research.google.com/github/malyajdas/AIARAG-Capstone-Project/blob/main/PythonBasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math as mt

# %%
print(mt.sqrt(15))
# Out:
# 3.872983346207417

# %%
print(mt.pi)
# Out:
# 3.141592653589793

# %%
lst = []
lst2 = list()

# %%
print(type(lst))
# Out:
# <class 'list'>

# %%
lst = [10, 20, 30, 40, 50]

# %%
print(lst)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(lst[1])
# Out:
# 20

# %%
print(lst[-4])
# Out:
# 20

# %%
print(lst[1:3])
# Out:
# [20, 30]
